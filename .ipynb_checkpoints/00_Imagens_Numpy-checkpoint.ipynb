# %% [markdown]
# # Imagens e Numpy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Biblioteca Pillow -> PIL --- Image

# %%
from PIL import Image

# %%
pic = Image.open('animals/00_Connie.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=535x951 at 0x7F2F97379BA8>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [197, 250, 254],
#         [196, 249, 255],
#         [179, 232, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [195, 253, 255],
#         [194, 252, 254],
#         [187, 245, 247]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [194, 254, 255],
#         [191, 251, 252],
#         [194, 254, 255]],
#
#        ...,
#
#        [[ 38,  34,  31],
#         [ 35,  31,  28],
#         [ 42,  41,  37],
#         ...,
#         [ 76,  71,  65],
#         [ 45,  42,  37],
#         [ 29,  28,  23]],
#
#        [[ 38,  34,  33],
#         [ 34,  30,  29],
#         [ 41,  40,  36],
#         ...,
#         [ 53,  48,  42],
#         [ 36,  33,  28],
#         [ 39,  38,  33]],
#
#        [[ 40,  36,  35],
#         [ 34,  30,  29],
#         [ 41,  40,  36],
# ...

# %% [markdown]
# ## Dimensão da imagem (pixel_v, pixel_h, canais)

# %%
pic_arr.shape
# Out:
# (951, 535, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy() #Copia para retirar o verde e o azul

# %%
pic_red[:,:,1]=0 #Contribuição do verde
pic_red[:,:,2]=0 #Contribuição do azul

# %%
plt.imshow(pic_red)
